# %% [markdown]
# <a href="https://colab.research.google.com/github/kevincruzortiz123-lgtm/programacion-2/blob/Programacioncodigos/26febrero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ADIVINA EL NÚMERO")
print("(entre 1 y 5, escribe 0 para salir)")
numero_secreto=3
while True:
  pass
  intento=int(input("¿Qué número crees que es?"))
  if intento==0:
    print("hasta luego")
    break
  if intento < 1 or intento > 5:
    print("Número fuera de rango, intenta de nuevo")
    continue
  if intento == numero_secreto:
    print("¡Correcto!")
    break
  else:
      print("Incorrecto, intenta de nuevo")
# Out:
# ADIVINA EL NÚMERO
# (entre 1 y 5, escribe 0 para salir)
# ¿Qué número crees que es?6
# Número fuera de rango, intenta de nuevo
# ¿Qué número crees que es?2
# Incorrecto, intenta de nuevo
# ¿Qué número crees que es?1
# Incorrecto, intenta de nuevo
# ¿Qué número crees que es?4
# Incorrecto, intenta de nuevo
# ¿Qué número crees que es?5
# Incorrecto, intenta de nuevo
# ¿Qué número crees que es?3
# ¡Correcto!

# %%
print("ADIVINA EL NÚMERO")
print("(Entre 1 y 5, escribe 0 para salir)")

numero_secreto = 3
numero_intentos = 2

while numero_intentos>0:

    intento = int(input("Adivina: "))
    if intento == 0:
        print("¡Hasta luego!")
        break
    if intento < 1 or intento > 5:
        print("Número fuera de rango, intenta de nuevo")
        numero_intentos -= 1
        if numero_intentos > 0:
            print(f"Quedan {numero_intentos} intentos")
        else:
            print("te quedaste sin intentos")
    elif intento == numero_secreto:
        print("¡Correcto! Adivinaste")
        break
    else:
        if numero_intentos > 0:
            numero_intentos -= 1
            print(f"Quedan {numero_intentos} intentos")
        else:
            print("Te quedaste sin intentos")
# Out:
# ADIVINA EL NÚMERO
# (Entre 1 y 5, escribe 0 para salir)
# Adivina: 345
# Número fuera de rango, intenta de nuevo
# Quedan 1 intentos
# Adivina: 897546312
# Número fuera de rango, intenta de nuevo
# te quedaste sin intentos
