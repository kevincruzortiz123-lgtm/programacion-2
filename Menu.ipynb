# %% [markdown]
# <a href="https://colab.research.google.com/github/kevincruzortiz123-lgtm/programacion-2/blob/menu/Menu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile menu.py
def mostrar_menu():
  print("MENU DE OPERACIONES CON MATRICES")
  print("1. Suma de matrices")
  print("2. Multiplicacion de matrices")
  print("3. Producto de hadamard")
  print("4. Producto de kronecker")
  print("5. Salir")

  while True:
    try:
      opcion = int(input("Ingrese una opcion: "))
      if opcion in [1,2,3,4,5]:
        return opcion
      else:
        print("Opcion invalida. Intente de nuevo.")
    except ValueError:
      print("Error. Ingrese un numero valido.")
